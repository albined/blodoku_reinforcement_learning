# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/albin/egna_proj/block_puzzle_rl/
# Out:
# /home/albin/egna_proj/block_puzzle_rl
# /home/albin/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# ⬇️ SB3 + Gym imports
import numpy as np
import torch
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from gymnasium import spaces
import numpy as np
import torch as th
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

# ⬇️ Your imports
from game.block_puzzle_env import BlockPuzzleEnv
from agent.utils import encode_state, encode_state_cnn
from game.block import random_block

# %%
# ⬇️ Custom wrapper to convert dict obs → flat array
class FlattenedBlockEnv(gym.Env):
    def __init__(self, width=12, height=12, num_blocks=3):
        super().__init__()
        self.raw_env = BlockPuzzleEnv(width, height, num_blocks)
        self.action_space = self.raw_env.action_space
        dummy_obs, _ = self.raw_env.reset()
        sample_obs = encode_state_cnn(dummy_obs)
        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=sample_obs.shape, dtype=np.uint8
        )
    
    def reset(self, seed=None, options=None):
        obs_dict, _ = self.raw_env.reset()
        flat_obs = encode_state_cnn(obs_dict)
        return flat_obs.astype(np.uint8), {}

    def step(self, action):
        # Handle batched action from DummyVecEnv (e.g., [0, 9, 10])
        if isinstance(action, (list, np.ndarray)) and len(action) == 3:
            a0, a1, a2 = map(int, action)
        else:
            # Flat index → unravel into (block_index, row, col)
            a0, a1, a2 = np.unravel_index(action, self.action_space.nvec)

        raw_action = (a0, a1, a2)
        (obs_dict, _), reward, terminated, truncated, info = self.raw_env.step(raw_action)
        flat_obs = encode_state_cnn(obs_dict)
        return flat_obs.astype(np.float32), reward, terminated, truncated, info


    def render(self):
        return self.raw_env.render()

    def close(self):
        return self.raw_env.close()


class DiscreteActionWrapper(gym.Env):
    def __init__(self, raw_env):
        super().__init__()
        self.raw_env = raw_env
        self.original_action_space = raw_env.action_space  # Should be MultiDiscrete
        self.obs_space = self.raw_env.observation_space

        # Flatten MultiDiscrete([a, b, c]) → Discrete(a * b * c)
        self.action_space = spaces.Discrete(np.prod(self.original_action_space.nvec))
        self.observation_space = spaces.Box(low=0, high=255, shape=encode_state_cnn(self.raw_env.reset()[0]).shape, dtype=np.uint8)

    def reset(self, **kwargs):
        obs_dict, _ = self.raw_env.reset(**kwargs)
        return encode_state_cnn(obs_dict).astype(np.uint8), {}

    def step(self, flat_action):
        a0, a1, a2 = np.unravel_index(flat_action, self.original_action_space.nvec)
        action = (int(a0), int(a1), int(a2))
        (obs_dict, _), reward, terminated, truncated, info = self.raw_env.step(action)
        flat_obs = encode_state_cnn(obs_dict)
        return flat_obs.astype(np.uint8), reward, terminated, truncated, info

    def render(self, **kwargs):
        return self.raw_env.render(**kwargs)

# %%
# ---- Custom CNN Features Extractor ----
class SmallCNN(BaseFeaturesExtractor):
    """
    Custom CNN for small grid inputs.
    Expects observation_space.shape = (C, H, W).
    """
    def __init__(self, observation_space: spaces.Box, features_dim: int = 256):
        super().__init__(observation_space, features_dim)
        height, width, n_input_channels = observation_space.shape

        # Convolutional layers with small kernels
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute the flattened dimension
        with th.no_grad():
            sample_input = th.zeros((1, n_input_channels, height, width))
            n_flatten = self.cnn(sample_input).shape[1]

        # Final fully-connected layer
        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        # Observations start as (B, H, W, C) and need to be permuted to (B, C, H, W)
        observations = observations.permute(0, 3, 1, 2)  # Change to (B, C, H, W)
        cnn_out = self.cnn(observations)
        return self.linear(cnn_out)

# %%
raw_env = BlockPuzzleEnv(width=12, height=12, num_blocks=3, block_function=random_block)
wrapped_env = DiscreteActionWrapper(raw_env)
monitored_env = Monitor(wrapped_env)

check_env(wrapped_env, warn=True)  # ✅ Now this should pass
vec_env = DummyVecEnv([lambda: monitored_env])

policy_kwargs = {
    "features_extractor_class": SmallCNN,
    "features_extractor_kwargs": {"features_dim": 256},
    # If your observations are float32 in [0.0,1.0], disable SB3 normalization:
    "normalize_images": False
}
# Out:
# /home/albin/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:76: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(

# %%
class CustomMetricsCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self):
        infos = self.locals["infos"]
        for info in infos:
            for key, value in info.items():
                if isinstance(value, np.ndarray):
                    self.logger.record(f"custom/{key}", value.mean())
                else:
                    self.logger.record(f"custom/{key}", value)
        return True

# %%
class CustomMetricsCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self):
        infos = self.locals["infos"]
        for info in infos:
            for key, value in info.items():
                if isinstance(value, np.ndarray):
                    self.logger.record(f"custom/{key}", value.mean())
                else:
                    self.logger.record(f"custom/{key}", value)
        return True

# %%
model = PPO(
    policy="CnnPolicy",  # or "CnnPolicy" if your input is image-like
    env=vec_env,
    learning_rate=1e-3,
    n_steps=8192,
    batch_size=256,
    n_epochs=10,
    gamma=0.99,
    verbose=1,
    tensorboard_log="./sb3_logs/", 
    policy_kwargs=policy_kwargs
)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=1000_000, tb_log_name="PPO_CNN", callback=CustomMetricsCallback())
model.save("sb3_block_ppo_cnn")
# Out:
# Logging to ./sb3_logs/PPO_CNN_10
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 5                                    |
# |    episode              | {'r': -253.8, 'l': 278, 't': 13.4... |
# |    invalid_moves        | 7932                                 |
# |    move_count           | 271                                  |
# |    terminal_observation | 0.12                                 |
# | rollout/                |                                      |
# |    ep_len_mean          | 821                                  |
# |    ep_rew_mean          | -790                                 |
# | time/                   |                                      |
# |    fps                  | 479                                  |
# |    iterations           | 1                                    |
# |    time_elapsed         | 17                                   |
# |    total_timesteps      | 8192                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 6                                    |
# |    episode              | {'r': -430.8, 'l': 455, 't': 34.2... |
# |    invalid_moves        | 15881                                |
# |    move_count           | 514                                  |
# |    terminal_observation | 0.0845                               |
# | rollout/                |                                      |
# |    ep_len_mean          | 937                                  |
# |    ep_rew_mean          | -906                                 |
# | time/                   |                                      |
# |    fps                  | 477                                  |
# |    iterations           | 2                                    |
# |    time_elapsed         | 34                                   |
# |    total_timesteps      | 16384                                |
# | train/                  |                                      |
# |    approx_kl            | 0.02177826                           |
# |    clip_fraction        | 0.301                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -6.05                                |
# |    explained_variance   | 0.05                                 |
# |    learning_rate        | 0.001                                |
# |    loss                 | 0.563                                |
# |    n_updates            | 10                                   |
# |    policy_gradient_loss | -0.0193                              |
# |    value_loss           | 21.2                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 16                                   |
# |    episode              | {'r': -296.8, 'l': 321, 't': 52.3... |
# |    invalid_moves        | 23885                                |
# |    move_count           | 702                                  |
# |    terminal_observation | 0.12                                 |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.06e+03                             |
# |    ep_rew_mean          | -1.03e+03                            |
# | time/                   |                                      |
# |    fps                  | 471                                  |
# |    iterations           | 3                                    |
# |    time_elapsed         | 52                                   |
# |    total_timesteps      | 24576                                |
# | train/                  |                                      |
# |    approx_kl            | 0.020931361                          |
# |    clip_fraction        | 0.239                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -6.04                                |
# |    explained_variance   | 0.174                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 1.15                                 |
# |    n_updates            | 20                                   |
# |    policy_gradient_loss | -0.00309                             |
# |    value_loss           | 35                                   |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 26                                   |
# |    episode              | {'r': -762.0, 'l': 795, 't': 69.1... |
# |    invalid_moves        | 31762                                |
# |    move_count           | 1017                                 |
# |    terminal_observation | 0.158                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 986                                  |
# |    ep_rew_mean          | -953                                 |
# | time/                   |                                      |
# |    fps                  | 476                                  |
# |    iterations           | 4                                    |
# |    time_elapsed         | 68                                   |
# |    total_timesteps      | 32768                                |
# | train/                  |                                      |
# |    approx_kl            | 0.021774104                          |
# |    clip_fraction        | 0.248                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -6.02                                |
# |    explained_variance   | 0.116                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 4.63                                 |
# |    n_updates            | 30                                   |
# |    policy_gradient_loss | -0.0106                              |
# |    value_loss           | 23.6                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 28                                   |
# |    episode              | {'r': -1276.9, 'l': 1311, 't': 87... |
# |    invalid_moves        | 39726                                |
# |    move_count           | 1245                                 |
# |    terminal_observation | 0.0835                               |
# | rollout/                |                                      |
# |    ep_len_mean          | 998                                  |
# |    ep_rew_mean          | -965                                 |
# | time/                   |                                      |
# |    fps                  | 469                                  |
# |    iterations           | 5                                    |
# |    time_elapsed         | 87                                   |
# |    total_timesteps      | 40960                                |
# | train/                  |                                      |
# |    approx_kl            | 0.022822998                          |
# |    clip_fraction        | 0.285                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.99                                |
# |    explained_variance   | 0.0781                               |
# |    learning_rate        | 0.001                                |
# |    loss                 | 11.7                                 |
# |    n_updates            | 40                                   |
# |    policy_gradient_loss | -0.0134                              |
# |    value_loss           | 26.7                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 35                                   |
# |    episode              | {'r': -3037.6, 'l': 3076, 't': 10... |
# |    invalid_moves        | 47808                                |
# |    move_count           | 1355                                 |
# |    terminal_observation | 0.0874                               |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.12e+03                             |
# |    ep_rew_mean          | -1.08e+03                            |
# | time/                   |                                      |
# |    fps                  | 473                                  |
# |    iterations           | 6                                    |
# |    time_elapsed         | 103                                  |
# |    total_timesteps      | 49152                                |
# | train/                  |                                      |
# |    approx_kl            | 0.02497289                           |
# |    clip_fraction        | 0.25                                 |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.98                                |
# |    explained_variance   | 0.151                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 9.31                                 |
# |    n_updates            | 50                                   |
# |    policy_gradient_loss | -0.0209                              |
# |    value_loss           | 24.4                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 40                                   |
# |    episode              | {'r': -1250.5, 'l': 1278, 't': 12... |
# |    invalid_moves        | 55801                                |
# |    move_count           | 1554                                 |
# |    terminal_observation | 0.121                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.14e+03                             |
# |    ep_rew_mean          | -1.1e+03                             |
# | time/                   |                                      |
# |    fps                  | 469                                  |
# |    iterations           | 7                                    |
# |    time_elapsed         | 122                                  |
# |    total_timesteps      | 57344                                |
# | train/                  |                                      |
# |    approx_kl            | 0.031159317                          |
# |    clip_fraction        | 0.33                                 |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.95                                |
# |    explained_variance   | 0.144                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 1.06                                 |
# |    n_updates            | 60                                   |
# |    policy_gradient_loss | -0.0169                              |
# |    value_loss           | 13.1                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 45                                   |
# |    episode              | {'r': -3343.8, 'l': 3393, 't': 13... |
# |    invalid_moves        | 63783                                |
# |    move_count           | 1764                                 |
# |    terminal_observation | 0.158                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.13e+03                             |
# |    ep_rew_mean          | -1.1e+03                             |
# | time/                   |                                      |
# |    fps                  | 471                                  |
# |    iterations           | 8                                    |
# |    time_elapsed         | 138                                  |
# |    total_timesteps      | 65536                                |
# | train/                  |                                      |
# |    approx_kl            | 0.028730791                          |
# |    clip_fraction        | 0.331                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.93                                |
# |    explained_variance   | 0.143                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 13.6                                 |
# |    n_updates            | 70                                   |
# |    policy_gradient_loss | -0.0187                              |
# |    value_loss           | 22.8                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 49                                   |
# |    episode              | {'r': -1650.6, 'l': 1690, 't': 15... |
# |    invalid_moves        | 71783                                |
# |    move_count           | 1956                                 |
# |    terminal_observation | 0.121                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.16e+03                             |
# |    ep_rew_mean          | -1.12e+03                            |
# | time/                   |                                      |
# |    fps                  | 466                                  |
# |    iterations           | 9                                    |
# |    time_elapsed         | 158                                  |
# |    total_timesteps      | 73728                                |
# | train/                  |                                      |
# |    approx_kl            | 0.02686406                           |
# |    clip_fraction        | 0.289                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.92                                |
# |    explained_variance   | 0.426                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 4.5                                  |
# |    n_updates            | 80                                   |
# |    policy_gradient_loss | -0.0233                              |
# |    value_loss           | 27.3                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 52                                   |
# |    episode              | {'r': -1759.6, 'l': 1799, 't': 17... |
# |    invalid_moves        | 79826                                |
# |    move_count           | 2105                                 |
# |    terminal_observation | 0.121                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.19e+03                             |
# |    ep_rew_mean          | -1.16e+03                            |
# | time/                   |                                      |
# |    fps                  | 467                                  |
# |    iterations           | 10                                   |
# |    time_elapsed         | 175                                  |
# |    total_timesteps      | 81920                                |
# | train/                  |                                      |
# |    approx_kl            | 0.029233875                          |
# |    clip_fraction        | 0.314                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.91                                |
# |    explained_variance   | 0.125                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 8.62                                 |
# |    n_updates            | 90                                   |
# |    policy_gradient_loss | -0.0224                              |
# |    value_loss           | 22.4                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 57                                   |
# |    episode              | {'r': -977.0, 'l': 1011, 't': 192... |
# |    invalid_moves        | 87897                                |
# |    move_count           | 2226                                 |
# |    terminal_observation | 0.197                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.24e+03                             |
# |    ep_rew_mean          | -1.2e+03                             |
# | time/                   |                                      |
# |    fps                  | 465                                  |
# |    iterations           | 11                                   |
# |    time_elapsed         | 193                                  |
# |    total_timesteps      | 90112                                |
# | train/                  |                                      |
# |    approx_kl            | 0.024030741                          |
# |    clip_fraction        | 0.301                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.9                                 |
# |    explained_variance   | 0.375                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 6.77                                 |
# |    n_updates            | 100                                  |
# |    policy_gradient_loss | -0.0242                              |
# |    value_loss           | 25.5                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 64                                   |
# |    episode              | {'r': -1049.0, 'l': 1082, 't': 20... |
# |    invalid_moves        | 95759                                |
# |    move_count           | 2556                                 |
# |    terminal_observation | 0.157                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.17e+03                             |
# |    ep_rew_mean          | -1.14e+03                            |
# | time/                   |                                      |
# |    fps                  | 465                                  |
# |    iterations           | 12                                   |
# |    time_elapsed         | 211                                  |
# |    total_timesteps      | 98304                                |
# | train/                  |                                      |
# |    approx_kl            | 0.037027057                          |
# |    clip_fraction        | 0.362                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.89                                |
# |    explained_variance   | 0.239                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 3.5                                  |
# |    n_updates            | 110                                  |
# |    policy_gradient_loss | -0.016                               |
# |    value_loss           | 16.7                                 |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | custom/                 |                                      |
# |    TimeLimit.truncated  | False                                |
# |    cleared_lines        | 70                                   |
# |    episode              | {'r': -1019.6, 'l': 1046, 't': 22... |
# |    invalid_moves        | 103768                               |
# |    move_count           | 2739                                 |
# |    terminal_observation | 0.152                                |
# | rollout/                |                                      |
# |    ep_len_mean          | 1.17e+03                             |
# |    ep_rew_mean          | -1.13e+03                            |
# | time/                   |                                      |
# |    fps                  | 464                                  |
# |    iterations           | 13                                   |
# |    time_elapsed         | 229                                  |
# |    total_timesteps      | 106496                               |
# | train/                  |                                      |
# |    approx_kl            | 0.025126226                          |
# |    clip_fraction        | 0.266                                |
# |    clip_range           | 0.2                                  |
# |    entropy_loss         | -5.85                                |
# |    explained_variance   | 0.165                                |
# |    learning_rate        | 0.001                                |
# |    loss                 | 23.5                                 |
# |    n_updates            | 120                                  |
# |    policy_gradient_loss | -0.0192                              |
# |    value_loss           | 41.9                                 |
# ------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.learn(total_timesteps=1000_000, tb_log_name="PPO_CNN", callback=CustomMetricsCallback())
#       2 model.save("sb3_block_ppo_cnn")
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/policies.py:647, in ActorCriticPolicy.forward(self, obs, deterministic)
#     645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
# --> 647     latent_pi, latent_vf = self.mlp_extractor(features)
#     648 else:
#     649     pi_features, vf_features = features
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/torch_layers.py:257, in MlpExtractor.forward(self, features)
#     252 def forward(self, features: th.Tensor) -> tuple[th.Tensor, th.Tensor]:
#     253     """
#     254     :return: latent_policy, latent_value of the specified network.
#     255         If all layers are shared, then ``latent_policy == latent_value``
#     256     """
# --> 257     return self.forward_actor(features), self.forward_critic(features)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/torch_layers.py:263, in MlpExtractor.forward_critic(self, features)
#     262 def forward_critic(self, features: th.Tensor) -> th.Tensor:
# --> 263     return self.value_net(features)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
