# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/albin/egna_proj/block_puzzle_rl/
# Out:
# /home/albin/egna_proj/block_puzzle_rl
# /home/albin/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import numpy as np
import torch
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from gymnasium import spaces
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
from collections import deque
from stable_baselines3.common.callbacks import CallbackList
from sb3_contrib import MaskablePPO
from game.plot_game import render_text
from sb3_contrib.common.maskable.utils import get_action_masks
from sb3_contrib.common.wrappers import ActionMasker
import os
from datetime import datetime
from game.block_puzzle_env import BlockPuzzleEnv
from agent.utils import encode_state, encode_state_cnn_modern
from sb3_utils.callbacks import AveragedMetricsCallback, SaveEveryNTimestepsCallback, UnfreezeCallback
import torch
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from game.plot_game import render_text_with_blocks

# %%
class DiscreteActionWrapper(gym.Env):
    def __init__(self, raw_env):
        super().__init__()
        self.raw_env = raw_env
        self.original_action_space = raw_env.action_space  # Should be MultiDiscrete
        self.obs_space = self.raw_env.observation_space
        
        dummy_obs, _ = self.raw_env.reset()
        grid, blocks = encode_state_cnn_modern(dummy_obs)


        # Flatten MultiDiscrete([a, b, c]) → Discrete(a * b * c)
        self.observation_space = spaces.Dict({
            'grid': spaces.Box(low=0.0, high=1.0, shape=(grid.shape), dtype=np.float32),
            'blocks': spaces.Box(low=0.0, high=1.0, shape=(blocks.shape), dtype=np.float32),
        })

        self.action_space = spaces.Discrete(np.prod(self.original_action_space.nvec))

    def reset(self, **kwargs):
        obs_dict, _ = self.raw_env.reset(**kwargs)
        grid, blocks = encode_state_cnn_modern(obs_dict)
        return {'grid': grid.astype(np.float32), 'blocks': blocks.astype(np.float32)}, {}

    def step(self, flat_action):
        a0, a1, a2 = np.unravel_index(flat_action, self.original_action_space.nvec)
        action = (int(a0), int(a1), int(a2))
        (obs_dict, _), reward, terminated, truncated, info = self.raw_env.step(action)
        grid, blocks = encode_state_cnn_modern(obs_dict)
        return {'grid': grid.astype(np.float32), 'blocks': blocks.astype(np.float32)}, reward, terminated, truncated, info

    def render(self, **kwargs):
        return self.raw_env.render(**kwargs)

# %%
raw_env = BlockPuzzleEnv(width=8, height=10, num_blocks=3)
wrapped_env = DiscreteActionWrapper(raw_env)
def mask_fn(env):
    return env.raw_env.game.compute_action_mask()
masked_env = ActionMasker(wrapped_env, mask_fn)
check_env(masked_env, warn=True)
# Out:
# /home/albin/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation blocks has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /home/albin/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation grid has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %%
class BlockPuzzleFeaturesExtended(BaseFeaturesExtractor):
    """
    A custom feature extractor that:
      - Takes obs = Dict({
            'grid':   Tensor of shape [batch, H, W],
            'blocks': Tensor of shape [batch, 3, P]
        })
      - Applies a small CNN to 'grid'
      - Applies a shared MLP to each of the 3 one-hot rows in 'blocks', sums them
      - Concatenates CNN features + summed-block features → output vector
    """
    def __init__(self, observation_space: gym.spaces.Dict,  cnn_channels=[16,32,32,64,64],  block_embedding_dim=64):
        # We know observation_space is a Dict with two entries:
        #   'grid':   Box(0,1, shape=(H, W), dtype=float32)
        #   'blocks': Box(0,1, shape=(3, P), dtype=float32)
        super().__init__(observation_space, features_dim=1)  # we’ll override features_dim below

        # 1) Extract shapes from the space:
        grid_shape   = observation_space.spaces['grid'].shape   # (H, W)
        blocks_shape = observation_space.spaces['blocks'].shape # (3, P)
        H, W         = grid_shape
        num_blocks, P = blocks_shape

        # 2) Build the CNN for 'grid' → produce a flat vector
        #    Input to CNN must have shape (batch, channels=1, H, W). We’ll unsqueeze in forward().
        self.cnn = nn.Sequential(
            nn.Conv2d(1,   cnn_channels[0], kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(cnn_channels[0], cnn_channels[1], kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(cnn_channels[1], cnn_channels[2], kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(cnn_channels[2], cnn_channels[3], kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(cnn_channels[3], cnn_channels[4], kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Flatten(),
        )
        

        # 3) Build the shared block‐embedding MLP (P → block_embedding_dim)
        self.block_mlp = nn.Sequential(
            nn.Linear(P,      128),
            nn.ReLU(),
            nn.Linear(128,    block_embedding_dim),
            nn.ReLU(),
        )

        # Figure out the CNN’s output size: pass a dummy tensor of shape (1,1,H,W)
        with torch.no_grad():
            H, W = observation_space.spaces['grid'].shape
            dummy = torch.zeros(1, 1, H, W)
            out = self.cnn(dummy)
            cnn_out_size = out.shape[1]

        # After embedding each of the 3 blocks, we will sum them into a single vector of size block_embedding_dim.

        # 4) Final joint MLP to combine [ CNN_out ∥ sum_of_block_embeddings ]
        joint_input_size = cnn_out_size + block_embedding_dim
        self.joint_net = nn.Sequential(
            nn.Linear(joint_input_size, 256),
            nn.ReLU(),
            nn.Linear(256,               128),
            nn.ReLU(),
        )

        # 5) Tell SB3 how large the final feature vector is:
        self._features_dim = 128

    def forward(self, observations: dict) -> torch.Tensor:
        """
        observations is a dict with:
          - 'grid':   torch.FloatTensor of shape (batch, H, W)
          - 'blocks': torch.FloatTensor of shape (batch, 3, P)
        We need to:
          1) Unsqueeze 'grid' → (batch, 1, H, W) → run through CNN → (batch, cnn_out_size)
          2) Flatten 'blocks' as (batch*3, P), run through block_mlp → (batch*3, block_embedding_dim),
             then reshape → (batch, 3, block_embedding_dim) → sum dim=1 → (batch, block_embedding_dim)
          3) Concatenate the two (batch, cnn_out_size + block_embedding_dim) → run through joint_net → (batch, 128)
        """
        # 1) CNN on 'grid'
        grid = observations['grid']            # shape = (batch, H, W), float32
        x    = grid.unsqueeze(1)               # → (batch, 1, H, W)
        x    = self.cnn(x)                     # → (batch, cnn_out_size)

        # 2) Embed & sum the 3 blocks
        blocks = observations['blocks']        # → (batch, 3, P)
        B, N, P = blocks.shape                  # B=batch, N=3, P=one-hot size
        blocks_flat = blocks.view(B * N, P)     # → (batch*3, P)
        e = self.block_mlp(blocks_flat)        # → (batch*3, block_embedding_dim)
        e = e.view(B, N, -1)                   # → (batch, 3, block_embedding_dim)
        e_sum = e.sum(dim=1)                   # → (batch, block_embedding_dim)

        # 3) Concatenate and pass through joint_net
        joint = torch.cat([x, e_sum], dim=1)    # → (batch, cnn_out_size + block_embedding_dim)
        return self.joint_net(joint)           # → (batch, 128)

# %%
def lr_warmup_schedule(progress_remaining) -> float:
    """
    SB3 passes in `progress_remaining` which goes from 1.0 → 0.0 over the entire learn() call.
    We want:
      - first 10% (progress 1.0 → 0.9): lr goes 1e-5 → 1e-3
      - remaining 90% (progress 0.9 → 0.0): lr goes 1e-3 → 1e-4
    """
    max_lr = 1e-3
    init_lr = 1e-5
    final_lr = 1e-4
    warmup_percent = 0.05  # 5% of the training time is warm-up

    # Calculate how far we are into training [0.0 .. 1.0]
    t = 1.0 - progress_remaining

    if t < warmup_percent:
        # warm-up phase: 0 → 0.05
        return init_lr + (max_lr - init_lr) * (t / warmup_percent)
    else:
        # decay phase: 0.05 → 1.0
        decay_t = (t - warmup_percent) / (1.0 - warmup_percent)  # remap [0.05..1.0] → [0..1]
        return max_lr + (final_lr - max_lr) * decay_t

# %%
def make_env():
    def _init():
        raw_env = BlockPuzzleEnv(width=8, height=10, num_blocks=3)
        wrapped_env = DiscreteActionWrapper(raw_env)

        def mask_fn(env):
            return env.raw_env.game.compute_action_mask()

        masked_env = ActionMasker(wrapped_env, mask_fn)
        monitored_env = Monitor(masked_env)
        return monitored_env

    return _init

n_envs = 32
vec_env = SubprocVecEnv([make_env() for _ in range(n_envs)])

policy_kwargs = dict(
    features_extractor_class  = BlockPuzzleFeaturesExtended,
    features_extractor_kwargs = dict(
        cnn_channels        = [16, 32, 32, 64, 64],   # or whatever you prefer
        block_embedding_dim = 64,
    ),
)

model = MaskablePPO(
    policy            = "MultiInputPolicy",
    env               = vec_env,
    learning_rate     = lr_warmup_schedule,
    n_steps           = 256,
    batch_size        = 4096,
    gamma             = 0.90,
    device            = "cuda",
    verbose           = 1,
    tensorboard_log   = "./sb3_logs/",
    policy_kwargs     = policy_kwargs,
)

callback_list = CallbackList([
    AveragedMetricsCallback(), 
    SaveEveryNTimestepsCallback(save_freq=250_000, save_path="./crash_backup_save/", name="backup_save", with_time=False, with_timesteps=False),
])

load_weights = False
weight_path = "sb3_block_ppo_cnn_modern_masked_50M"
if load_weights:
    model.set_parameters(weight_path, exact_match=False)


model.learn(total_timesteps=100_000_000, callback=callback_list, tb_log_name="PPO_CNN_MODERN_MASKED_DEEPER")
model.save("sb3_block_ppo_cnn_modern_masked_deeper")
# Out:
# Using cuda device
# Logging to ./sb3_logs/PPO_CNN_MODERN_MASKED_DEEPER_1
# -----------------------------------
# | custom/              |          |
# |    cleared_lines_avg | 1.1      |
# |    invalid_moves_avg | 0        |
# |    move_count_avg    | 17.3     |
# | rollout/             |          |
# |    ep_len_mean       | 17.3     |
# |    ep_rew_mean       | -8.26    |
# | time/                |          |
# |    fps               | 4042     |
# |    iterations        | 1        |
# |    time_elapsed      | 2        |
# |    total_timesteps   | 8192     |
# -----------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.3          |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.8         |
# | rollout/                |              |
# |    ep_len_mean          | 17.8         |
# |    ep_rew_mean          | -7.85        |
# | time/                   |              |
# |    fps                  | 3854         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 6.527189e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | -0.0362      |
# |    learning_rate        | 1.16e-05     |
# |    loss                 | 7.16         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -7.31e-05    |
# |    value_loss           | 17.5         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.12          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.2          |
# | rollout/                |               |
# |    ep_len_mean          | 17.2          |
# |    ep_rew_mean          | -8.11         |
# | time/                   |               |
# |    fps                  | 3943          |
# |    iterations           | 3             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.1280281e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.0789        |
# |    learning_rate        | 1.32e-05      |
# |    loss                 | 5.3           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -7.69e-05     |
# |    value_loss           | 12            |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.17          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.2          |
# | rollout/                |               |
# |    ep_len_mean          | 17.2          |
# |    ep_rew_mean          | -8.21         |
# | time/                   |               |
# |    fps                  | 3928          |
# |    iterations           | 4             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 5.1609313e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.112         |
# |    learning_rate        | 1.49e-05      |
# |    loss                 | 4.57          |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 9.64          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.23          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.4          |
# | rollout/                |               |
# |    ep_len_mean          | 17.4          |
# |    ep_rew_mean          | -8.13         |
# | time/                   |               |
# |    fps                  | 3953          |
# |    iterations           | 5             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.5818492e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.121         |
# |    learning_rate        | 1.65e-05      |
# |    loss                 | 4.37          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000368     |
# |    value_loss           | 8.82          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.24          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.7          |
# | rollout/                |               |
# |    ep_len_mean          | 17.7          |
# |    ep_rew_mean          | -7.87         |
# | time/                   |               |
# |    fps                  | 3966          |
# |    iterations           | 6             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 2.8027302e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.133         |
# |    learning_rate        | 1.81e-05      |
# |    loss                 | 3.94          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000521     |
# |    value_loss           | 7.91          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.59          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.7          |
# | rollout/                |               |
# |    ep_len_mean          | 18.7          |
# |    ep_rew_mean          | -7.2          |
# | time/                   |               |
# |    fps                  | 3973          |
# |    iterations           | 7             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 2.4112764e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.165         |
# |    learning_rate        | 1.97e-05      |
# |    loss                 | 4             |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000445     |
# |    value_loss           | 7.98          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.11          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.2          |
# | rollout/                |               |
# |    ep_len_mean          | 17.2          |
# |    ep_rew_mean          | -8.18         |
# | time/                   |               |
# |    fps                  | 3687          |
# |    iterations           | 8             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 3.5111545e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.185         |
# |    learning_rate        | 2.14e-05      |
# |    loss                 | 3.72          |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00055      |
# |    value_loss           | 7.78          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.29          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18            |
# | rollout/                |               |
# |    ep_len_mean          | 18            |
# |    ep_rew_mean          | -7.96         |
# | time/                   |               |
# |    fps                  | 3705          |
# |    iterations           | 9             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 3.7738362e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.23          |
# |    learning_rate        | 2.3e-05       |
# |    loss                 | 3.58          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000559     |
# |    value_loss           | 7.26          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.55         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 18.1         |
# | rollout/                |              |
# |    ep_len_mean          | 18.1         |
# |    ep_rew_mean          | -7.27        |
# | time/                   |              |
# |    fps                  | 3740         |
# |    iterations           | 10           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 5.514155e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 2.46e-05     |
# |    loss                 | 3.59         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000694    |
# |    value_loss           | 7.17         |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.21         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.5         |
# | rollout/                |              |
# |    ep_len_mean          | 17.5         |
# |    ep_rew_mean          | -7.99        |
# | time/                   |              |
# |    fps                  | 3760         |
# |    iterations           | 11           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 7.801023e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 2.62e-05     |
# |    loss                 | 3.67         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00081     |
# |    value_loss           | 7.5          |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 0.96          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 16.6          |
# | rollout/                |               |
# |    ep_len_mean          | 16.6          |
# |    ep_rew_mean          | -8.57         |
# | time/                   |               |
# |    fps                  | 3787          |
# |    iterations           | 12            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 4.2369837e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.271         |
# |    learning_rate        | 2.78e-05      |
# |    loss                 | 3.25          |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000486     |
# |    value_loss           | 6.78          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.57          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.4          |
# | rollout/                |               |
# |    ep_len_mean          | 18.4          |
# |    ep_rew_mean          | -7.2          |
# | time/                   |               |
# |    fps                  | 3813          |
# |    iterations           | 13            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 3.8363658e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.27          |
# |    learning_rate        | 2.95e-05      |
# |    loss                 | 3.25          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000555     |
# |    value_loss           | 6.6           |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.17         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.7         |
# | rollout/                |              |
# |    ep_len_mean          | 17.7         |
# |    ep_rew_mean          | -8.13        |
# | time/                   |              |
# |    fps                  | 3837         |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 7.577011e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 3.11e-05     |
# |    loss                 | 3.74         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000725    |
# |    value_loss           | 7.83         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.09          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.1          |
# | rollout/                |               |
# |    ep_len_mean          | 17.1          |
# |    ep_rew_mean          | -8.19         |
# | time/                   |               |
# |    fps                  | 3856          |
# |    iterations           | 15            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 6.0336708e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.307         |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | 3.03          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000616     |
# |    value_loss           | 6.02          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.27         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.7         |
# | rollout/                |              |
# |    ep_len_mean          | 17.7         |
# |    ep_rew_mean          | -7.94        |
# | time/                   |              |
# |    fps                  | 3871         |
# |    iterations           | 16           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 7.264019e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 3.43e-05     |
# |    loss                 | 3.01         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000758    |
# |    value_loss           | 6.36         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 0.98          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.1          |
# | rollout/                |               |
# |    ep_len_mean          | 17.1          |
# |    ep_rew_mean          | -8.59         |
# | time/                   |               |
# |    fps                  | 3889          |
# |    iterations           | 17            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 139264        |
# | train/                  |               |
# |    approx_kl            | 8.4751424e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.259         |
# |    learning_rate        | 3.6e-05       |
# |    loss                 | 3.57          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000801     |
# |    value_loss           | 6.88          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.04         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 16.9         |
# | rollout/                |              |
# |    ep_len_mean          | 16.9         |
# |    ep_rew_mean          | -8.37        |
# | time/                   |              |
# |    fps                  | 3901         |
# |    iterations           | 18           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 7.500289e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.21        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 3.76e-05     |
# |    loss                 | 3.32         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000739    |
# |    value_loss           | 6.68         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.26          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.2          |
# | rollout/                |               |
# |    ep_len_mean          | 18.2          |
# |    ep_rew_mean          | -7.98         |
# | time/                   |               |
# |    fps                  | 3904          |
# |    iterations           | 19            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 5.1646668e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.24         |
# |    explained_variance   | 0.294         |
# |    learning_rate        | 3.92e-05      |
# |    loss                 | 3.18          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000608     |
# |    value_loss           | 6.34          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.41          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.2          |
# | rollout/                |               |
# |    ep_len_mean          | 18.2          |
# |    ep_rew_mean          | -7.49         |
# | time/                   |               |
# |    fps                  | 3908          |
# |    iterations           | 20            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 163840        |
# | train/                  |               |
# |    approx_kl            | 0.00010455601 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.288         |
# |    learning_rate        | 4.08e-05      |
# |    loss                 | 3.19          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000848     |
# |    value_loss           | 6.29          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.13         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.2         |
# | rollout/                |              |
# |    ep_len_mean          | 17.2         |
# |    ep_rew_mean          | -8.48        |
# | time/                   |              |
# |    fps                  | 3913         |
# |    iterations           | 21           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 7.092885e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 4.24e-05     |
# |    loss                 | 3.34         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000539    |
# |    value_loss           | 6.95         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.17          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.6          |
# | rollout/                |               |
# |    ep_len_mean          | 17.6          |
# |    ep_rew_mean          | -8.07         |
# | time/                   |               |
# |    fps                  | 3918          |
# |    iterations           | 22            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00014255758 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.279         |
# |    learning_rate        | 4.41e-05      |
# |    loss                 | 3.17          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 6.42          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.21          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.6          |
# | rollout/                |               |
# |    ep_len_mean          | 17.6          |
# |    ep_rew_mean          | -8.25         |
# | time/                   |               |
# |    fps                  | 3925          |
# |    iterations           | 23            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00013807861 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.19         |
# |    explained_variance   | 0.284         |
# |    learning_rate        | 4.57e-05      |
# |    loss                 | 3.2           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000908     |
# |    value_loss           | 6.47          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.67          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.7          |
# | rollout/                |               |
# |    ep_len_mean          | 18.7          |
# |    ep_rew_mean          | -7.38         |
# | time/                   |               |
# |    fps                  | 3830          |
# |    iterations           | 24            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00014669061 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.255         |
# |    learning_rate        | 4.73e-05      |
# |    loss                 | 3.5           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000935     |
# |    value_loss           | 7.18          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.04          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.1          |
# | rollout/                |               |
# |    ep_len_mean          | 17.1          |
# |    ep_rew_mean          | -8.45         |
# | time/                   |               |
# |    fps                  | 3830          |
# |    iterations           | 25            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 204800        |
# | train/                  |               |
# |    approx_kl            | 0.00016598444 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.19         |
# |    explained_variance   | 0.206         |
# |    learning_rate        | 4.89e-05      |
# |    loss                 | 3.64          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 7.71          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.16          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.5          |
# | rollout/                |               |
# |    ep_len_mean          | 17.5          |
# |    ep_rew_mean          | -8.1          |
# | time/                   |               |
# |    fps                  | 3838          |
# |    iterations           | 26            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 212992        |
# | train/                  |               |
# |    approx_kl            | 8.8870634e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.323         |
# |    learning_rate        | 5.06e-05      |
# |    loss                 | 2.97          |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000659     |
# |    value_loss           | 6.06          |
# -------------------------------------------
# --------------------------------------------
# | custom/                 |                |
# |    cleared_lines_avg    | 1.2            |
# |    invalid_moves_avg    | 0              |
# |    move_count_avg       | 17.4           |
# | rollout/                |                |
# |    ep_len_mean          | 17.4           |
# |    ep_rew_mean          | -7.98          |
# | time/                   |                |
# |    fps                  | 3842           |
# |    iterations           | 27             |
# |    time_elapsed         | 57             |
# |    total_timesteps      | 221184         |
# | train/                  |                |
# |    approx_kl            | 0.000101408696 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -3.22          |
# |    explained_variance   | 0.289          |
# |    learning_rate        | 5.22e-05       |
# |    loss                 | 2.97           |
# |    n_updates            | 260            |
# |    policy_gradient_loss | -0.000895      |
# |    value_loss           | 6.45           |
# --------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.31          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.9          |
# | rollout/                |               |
# |    ep_len_mean          | 17.9          |
# |    ep_rew_mean          | -7.63         |
# | time/                   |               |
# |    fps                  | 3846          |
# |    iterations           | 28            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 229376        |
# | train/                  |               |
# |    approx_kl            | 0.00019023012 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0.251         |
# |    learning_rate        | 5.38e-05      |
# |    loss                 | 3.35          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 6.85          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.02          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.1          |
# | rollout/                |               |
# |    ep_len_mean          | 17.1          |
# |    ep_rew_mean          | -8.25         |
# | time/                   |               |
# |    fps                  | 3854          |
# |    iterations           | 29            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 237568        |
# | train/                  |               |
# |    approx_kl            | 0.00010822475 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.23         |
# |    explained_variance   | 0.289         |
# |    learning_rate        | 5.54e-05      |
# |    loss                 | 3.34          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000727     |
# |    value_loss           | 6.59          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.54          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.1          |
# | rollout/                |               |
# |    ep_len_mean          | 18.1          |
# |    ep_rew_mean          | -7.38         |
# | time/                   |               |
# |    fps                  | 3858          |
# |    iterations           | 30            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 245760        |
# | train/                  |               |
# |    approx_kl            | 0.00014873676 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.22         |
# |    explained_variance   | 0.315         |
# |    learning_rate        | 5.7e-05       |
# |    loss                 | 2.96          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 6.01          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.22          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.5          |
# | rollout/                |               |
# |    ep_len_mean          | 17.5          |
# |    ep_rew_mean          | -8            |
# | time/                   |               |
# |    fps                  | 3862          |
# |    iterations           | 31            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 253952        |
# | train/                  |               |
# |    approx_kl            | 0.00011948392 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.19         |
# |    explained_variance   | 0.217         |
# |    learning_rate        | 5.87e-05      |
# |    loss                 | 3.68          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00066      |
# |    value_loss           | 7.67          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.77          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 19.1          |
# | rollout/                |               |
# |    ep_len_mean          | 19.1          |
# |    ep_rew_mean          | -6.96         |
# | time/                   |               |
# |    fps                  | 3864          |
# |    iterations           | 32            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 262144        |
# | train/                  |               |
# |    approx_kl            | 0.00010061028 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.248         |
# |    learning_rate        | 6.03e-05      |
# |    loss                 | 3.53          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000928     |
# |    value_loss           | 7.47          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.35          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.3          |
# | rollout/                |               |
# |    ep_len_mean          | 18.3          |
# |    ep_rew_mean          | -7.66         |
# | time/                   |               |
# |    fps                  | 3869          |
# |    iterations           | 33            |
# |    time_elapsed         | 69            |
# |    total_timesteps      | 270336        |
# | train/                  |               |
# |    approx_kl            | 7.0238835e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.17         |
# |    explained_variance   | 0.161         |
# |    learning_rate        | 6.19e-05      |
# |    loss                 | 4.29          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.0006       |
# |    value_loss           | 8.75          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.16         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.5         |
# | rollout/                |              |
# |    ep_len_mean          | 17.5         |
# |    ep_rew_mean          | -8.05        |
# | time/                   |              |
# |    fps                  | 3872         |
# |    iterations           | 34           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 7.293965e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 6.35e-05     |
# |    loss                 | 3.36         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000626    |
# |    value_loss           | 7.2          |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.31         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.6         |
# | rollout/                |              |
# |    ep_len_mean          | 17.6         |
# |    ep_rew_mean          | -7.9         |
# | time/                   |              |
# |    fps                  | 3875         |
# |    iterations           | 35           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 4.985019e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 6.51e-05     |
# |    loss                 | 3.11         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000546    |
# |    value_loss           | 6.28         |
# ------------------------------------------
# --------------------------------------------
# | custom/                 |                |
# |    cleared_lines_avg    | 1.23           |
# |    invalid_moves_avg    | 0              |
# |    move_count_avg       | 17.3           |
# | rollout/                |                |
# |    ep_len_mean          | 17.3           |
# |    ep_rew_mean          | -7.88          |
# | time/                   |                |
# |    fps                  | 3877           |
# |    iterations           | 36             |
# |    time_elapsed         | 76             |
# |    total_timesteps      | 294912         |
# | train/                  |                |
# |    approx_kl            | 0.000100513964 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -3.22          |
# |    explained_variance   | 0.286          |
# |    learning_rate        | 6.68e-05       |
# |    loss                 | 3.19           |
# |    n_updates            | 350            |
# |    policy_gradient_loss | -0.000873      |
# |    value_loss           | 6.61           |
# --------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.37          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.6          |
# | rollout/                |               |
# |    ep_len_mean          | 17.6          |
# |    ep_rew_mean          | -7.64         |
# | time/                   |               |
# |    fps                  | 3880          |
# |    iterations           | 37            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 303104        |
# | train/                  |               |
# |    approx_kl            | 0.00014754842 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0.26          |
# |    learning_rate        | 6.84e-05      |
# |    loss                 | 3.26          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000841     |
# |    value_loss           | 6.81          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.52          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.2          |
# | rollout/                |               |
# |    ep_len_mean          | 18.2          |
# |    ep_rew_mean          | -7.46         |
# | time/                   |               |
# |    fps                  | 3884          |
# |    iterations           | 38            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 311296        |
# | train/                  |               |
# |    approx_kl            | 0.00017575704 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.2          |
# |    explained_variance   | 0.255         |
# |    learning_rate        | 7e-05         |
# |    loss                 | 3.43          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000815     |
# |    value_loss           | 7.1           |
# -------------------------------------------
# --------------------------------------------
# | custom/                 |                |
# |    cleared_lines_avg    | 1.24           |
# |    invalid_moves_avg    | 0              |
# |    move_count_avg       | 17.4           |
# | rollout/                |                |
# |    ep_len_mean          | 17.4           |
# |    ep_rew_mean          | -8.02          |
# | time/                   |                |
# |    fps                  | 3887           |
# |    iterations           | 39             |
# |    time_elapsed         | 82             |
# |    total_timesteps      | 319488         |
# | train/                  |                |
# |    approx_kl            | 0.000116252835 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -3.16          |
# |    explained_variance   | 0.229          |
# |    learning_rate        | 7.16e-05       |
# |    loss                 | 3.74           |
# |    n_updates            | 380            |
# |    policy_gradient_loss | -0.00104       |
# |    value_loss           | 7.53           |
# --------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.27          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.7          |
# | rollout/                |               |
# |    ep_len_mean          | 17.7          |
# |    ep_rew_mean          | -7.98         |
# | time/                   |               |
# |    fps                  | 3831          |
# |    iterations           | 40            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 327680        |
# | train/                  |               |
# |    approx_kl            | 3.4910212e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.24         |
# |    explained_variance   | 0.304         |
# |    learning_rate        | 7.33e-05      |
# |    loss                 | 3.29          |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000277     |
# |    value_loss           | 6.52          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.7           |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 19.1          |
# | rollout/                |               |
# |    ep_len_mean          | 19.1          |
# |    ep_rew_mean          | -6.95         |
# | time/                   |               |
# |    fps                  | 3835          |
# |    iterations           | 41            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 335872        |
# | train/                  |               |
# |    approx_kl            | 0.00022392762 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.24         |
# |    explained_variance   | 0.309         |
# |    learning_rate        | 7.49e-05      |
# |    loss                 | 3.08          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.00125      |
# |    value_loss           | 6.22          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.59          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 18.8          |
# | rollout/                |               |
# |    ep_len_mean          | 18.8          |
# |    ep_rew_mean          | -7.35         |
# | time/                   |               |
# |    fps                  | 3841          |
# |    iterations           | 42            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 344064        |
# | train/                  |               |
# |    approx_kl            | 0.00011086759 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.19         |
# |    explained_variance   | 0.207         |
# |    learning_rate        | 7.65e-05      |
# |    loss                 | 3.93          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000569     |
# |    value_loss           | 7.99          |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 1.31         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 17.5         |
# | rollout/                |              |
# |    ep_len_mean          | 17.5         |
# |    ep_rew_mean          | -7.84        |
# | time/                   |              |
# |    fps                  | 3846         |
# |    iterations           | 43           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 6.938004e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 7.81e-05     |
# |    loss                 | 3.57         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000776    |
# |    value_loss           | 7.17         |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 1.15          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 17.4          |
# | rollout/                |               |
# |    ep_len_mean          | 17.4          |
# |    ep_rew_mean          | -8.07         |
# | time/                   |               |
# |    fps                  | 3854          |
# |    iterations           | 44            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 360448        |
# | train/                  |               |
# |    approx_kl            | 0.00019098233 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.21         |
# |    explained_variance   | 0.298         |
# |    learning_rate        | 7.97e-05      |
# |    loss                 | 3.29          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 6.63          |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    cleared_lines_avg    | 0.95          |
# |    invalid_moves_avg    | 0             |
# |    move_count_avg       | 16.9          |
# | rollout/                |               |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0053579602 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.000975     |
# |    loss                 | 3.02         |
# |    n_updates            | 9330         |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 10.5         |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 7.89         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 33.2         |
# | rollout/                |              |
# |    ep_len_mean          | 33.2         |
# |    ep_rew_mean          | 3.75         |
# | time/                   |              |
# |    fps                  | 3913         |
# |    iterations           | 935          |
# |    time_elapsed         | 1957         |
# |    total_timesteps      | 7659520      |
# | train/                  |              |
# |    approx_kl            | 0.0071424483 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.000975     |
# |    loss                 | 2.61         |
# |    n_updates            | 9340         |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 9.96         |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    cleared_lines_avg    | 7.84         |
# |    invalid_moves_avg    | 0            |
# |    move_count_avg       | 33           |
# | rollout/                |              |
# |    ep_len_mean          | 33           |
# |    ep_rew_mean          | 3.73         |
# | time/                   |              |
# |    fps                  | 3913         |
# |    iterations           | 936          |
# |    time_elapsed         | 1959         |
# |    total_timesteps      | 7667712      |
# | train/                  |              |
# |    approx_kl            | 0.0062247813 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.000975     |
# |    loss                 | 2.57         |
# |    n_updates            | 9350         |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 9.25         |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.51        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 31.9        |
# | rollout/                |             |
# |    ep_len_mean          | 31.9        |
# |    ep_rew_mean          | 3.09        |
# | time/                   |             |
# |    fps                  | 3913        |
# |    iterations           | 937         |
# |    time_elapsed         | 1961        |
# |    total_timesteps      | 7675904     |
# | train/                  |             |
# |    approx_kl            | 0.008364438 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.000975    |
# |    loss                 | 2.43        |
# |    n_updates            | 9360        |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 9.46        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.5         |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 32.1        |
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 3.46        |
# | time/                   |             |
# |    fps                  | 3913        |
# |    iterations           | 938         |
# |    time_elapsed         | 1963        |
# |    total_timesteps      | 7684096     |
# | train/                  |             |
# |    approx_kl            | 0.007911092 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.000975    |
# |    loss                 | 2.27        |
# |    n_updates            | 9370        |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 9.52        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 8.02        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 33.3        |
# | rollout/                |             |
# |    ep_len_mean          | 33.3        |
# |    ep_rew_mean          | 4.4         |
# | time/                   |             |
# |    fps                  | 3914        |
# |    iterations           | 939         |
# |    time_elapsed         | 1965        |
# |    total_timesteps      | 7692288     |
# | train/                  |             |
# |    approx_kl            | 0.007810924 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.000975    |
# |    loss                 | 2.46        |
# |    n_updates            | 9380        |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 9.44        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.09        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 31          |
# | rollout/                |             |
# |    ep_len_mean          | 31          |
# |    ep_rew_mean          | 2.26        |
# | time/                   |             |
# |    fps                  | 3914        |
# |    iterations           | 940         |
# |    time_elapsed         | 1967        |
# |    total_timesteps      | 7700480     |
# | train/                  |             |
# |    approx_kl            | 0.007187008 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.54        |
# |    n_updates            | 9390        |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.98        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 33.5        |
# | rollout/                |             |
# |    ep_len_mean          | 33.5        |
# |    ep_rew_mean          | 3.9         |
# | time/                   |             |
# |    fps                  | 3914        |
# |    iterations           | 941         |
# |    time_elapsed         | 1969        |
# |    total_timesteps      | 7708672     |
# | train/                  |             |
# |    approx_kl            | 0.006830385 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.48        |
# |    n_updates            | 9400        |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 9.48        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 8.12        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 33.7        |
# | rollout/                |             |
# |    ep_len_mean          | 33.7        |
# |    ep_rew_mean          | 4.77        |
# | time/                   |             |
# |    fps                  | 3915        |
# |    iterations           | 942         |
# |    time_elapsed         | 1971        |
# |    total_timesteps      | 7716864     |
# | train/                  |             |
# |    approx_kl            | 0.009310072 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.45        |
# |    n_updates            | 9410        |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 9.3         |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.31        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 31.8        |
# | rollout/                |             |
# |    ep_len_mean          | 31.8        |
# |    ep_rew_mean          | 2.27        |
# | time/                   |             |
# |    fps                  | 3915        |
# |    iterations           | 943         |
# |    time_elapsed         | 1973        |
# |    total_timesteps      | 7725056     |
# | train/                  |             |
# |    approx_kl            | 0.007793664 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.48        |
# |    n_updates            | 9420        |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 9.64        |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 7.79        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 32.9        |
# | rollout/                |             |
# |    ep_len_mean          | 32.9        |
# |    ep_rew_mean          | 3.95        |
# | time/                   |             |
# |    fps                  | 3915        |
# |    iterations           | 944         |
# |    time_elapsed         | 1975        |
# |    total_timesteps      | 7733248     |
# | train/                  |             |
# |    approx_kl            | 0.009061264 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.67        |
# |    n_updates            | 9430        |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 9.21        |
# -----------------------------------------
# ----------------------------------------
# | custom/                 |            |
# |    cleared_lines_avg    | 7.97       |
# |    invalid_moves_avg    | 0          |
# |    move_count_avg       | 33.4       |
# | rollout/                |            |
# |    ep_len_mean          | 33.4       |
# |    ep_rew_mean          | 4.62       |
# | time/                   |            |
# |    fps                  | 3912       |
# |    iterations           | 945        |
# |    time_elapsed         | 1978       |
# |    total_timesteps      | 7741440    |
# | train/                  |            |
# |    approx_kl            | 0.00629742 |
# |    clip_fraction        | 0.0359     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.453     |
# |    explained_variance   | 0.198      |
# |    learning_rate        | 0.000974   |
# |    loss                 | 2.8        |
# |    n_updates            | 9440       |
# |    policy_gradient_loss | -0.00412   |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    cleared_lines_avg    | 6.78        |
# |    invalid_moves_avg    | 0           |
# |    move_count_avg       | 30.4        |
# | rollout/                |             |
# |    ep_len_mean          | 30.4        |
# |    ep_rew_mean          | 1.68        |
# | time/                   |             |
# |    fps                  | 3912        |
# |    iterations           | 946         |
# |    time_elapsed         | 1980        |
# |    total_timesteps      | 7749632     |
# | train/                  |             |
# |    approx_kl            | 0.008214959 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.000974    |
# |    loss                 | 2.99        |
# |    n_updates            | 9450        |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 10.1        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 50
#      46 if load_weights:
#      47     model.set_parameters(weight_path, exact_match=False)
# ---> 50 model.learn(total_timesteps=100_000_000, callback=callback_list, tb_log_name="PPO_CNN_MODERN_MASKED_DEEPER")
#      51 model.save("sb3_block_ppo_cnn_modern_masked_deeper")
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:454, in MaskablePPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, use_masking, progress_bar)
#     451 assert self.env is not None
#     453 while self.num_timesteps < total_timesteps:
# --> 454     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, self.n_steps, use_masking)
#     456     if not continue_training:
#     457         break
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:233, in MaskablePPO.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps, use_masking)
#     230     actions, values, log_probs = self.policy(obs_tensor, action_masks=action_masks)
#     232 actions = actions.cpu().numpy()
# --> 233 new_obs, rewards, dones, infos = env.step(actions)
#     235 self.num_timesteps += env.num_envs
#     237 # Give access to local variables
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py:137, in SubprocVecEnv.step_wait(self)
#     136 def step_wait(self) -> VecEnvStepReturn:
# --> 137     results = [remote.recv() for remote in self.remotes]
#     138     self.waiting = False
#     139     obs, rews, dones, infos, self.reset_infos = zip(*results)  # type: ignore[assignment]
#
# File ~/egna_proj/block_puzzle_rl/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py:137, in <listcomp>(.0)
#     136 def step_wait(self) -> VecEnvStepReturn:
# --> 137     results = [remote.recv() for remote in self.remotes]
#     138     self.waiting = False
#     139     obs, rews, dones, infos, self.reset_infos = zip(*results)  # type: ignore[assignment]
#
# File /usr/lib/python3.10/multiprocessing/connection.py:251, in _ConnectionBase.recv(self)
#     249 self._check_readable()
#     250 buf = self._recv_bytes()
# --> 251 return _ForkingPickler.loads(buf.getbuffer())
#
# KeyboardInterrupt:

# %%
model.save("sb3_block_ppo_cnn_modern_masked_deeper")

# %%
# callback_list = CallbackList([
#     AveragedMetricsCallback(), 
#     SaveEveryNTimestepsCallback(save_freq=1_000_000, save_path="./sb3_model_saves/", name="sb3_block_ppo_mlp_masked_rewards2"),
#     SaveEveryNTimestepsCallback(save_freq=100_000, save_path="./crash_backup_save/", name="backup_save", with_time=False, with_timesteps=False),
# ])

# for i in range(0, 50):
#     if i != 0:
#         backup_path = "crash_backup_save/backup_save__"
#         model.set_parameters(backup_path, exact_match=True)

#     try:
#         model.learn(total_timesteps=30_000_001, callback=callback_list, tb_log_name="PPO_MLP_MASKED")
#     except Exception as e:
#         pass

# %%
single_env = DiscreteActionWrapper(BlockPuzzleEnv(width=8, height=10, num_blocks=3))
obs, _ = single_env.reset()
done = False
total_reward = 0
step = 0

while not done:
    # Get valid action mask
    mask = single_env.raw_env.game.compute_action_mask()
        
    # Use model.predict with action_masks for MaskablePPO
    action, _ = model.predict(obs, action_masks=mask, deterministic=True)
    
    obs, reward, terminated, truncated, info = single_env.step(action)
    total_reward += reward
    done = terminated or truncated
    step += 1
    
    game_grid = single_env.raw_env.game.grid.get_game_grid()
    game_blocks = [block.grid() for block in single_env.raw_env.game.block_queue]

    render_text_with_blocks(game_grid, game_blocks)
    print()


print(f"Evaluation finished in {step} steps, total reward: {total_reward}")

# %%
game_grid
